# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob
import h5py
import os

# %%
image_list=glob('../../data/BCData/images/train/*.png')
label_list=[f.replace('images','annotations').replace("train/",'train/positive/').replace('.png','.h5') for f in image_list]
# Out:
# ['../../data/BCData/annotations/train/positive/0.h5',
#  '../../data/BCData/annotations/train/positive/1.h5',
#  '../../data/BCData/annotations/train/positive/10.h5',
#  '../../data/BCData/annotations/train/positive/100.h5',
#  '../../data/BCData/annotations/train/positive/101.h5',
#  '../../data/BCData/annotations/train/positive/102.h5',
#  '../../data/BCData/annotations/train/positive/103.h5',
#  '../../data/BCData/annotations/train/positive/104.h5',
#  '../../data/BCData/annotations/train/positive/105.h5',
#  '../../data/BCData/annotations/train/positive/106.h5',
#  '../../data/BCData/annotations/train/positive/107.h5',
#  '../../data/BCData/annotations/train/positive/108.h5',
#  '../../data/BCData/annotations/train/positive/109.h5',
#  '../../data/BCData/annotations/train/positive/11.h5',
#  '../../data/BCData/annotations/train/positive/110.h5',
#  '../../data/BCData/annotations/train/positive/111.h5',
#  '../../data/BCData/annotations/train/positive/112.h5',
# ...

# %%
gt_path = label_list[0]

gt_file = h5py.File(gt_path)
coordinates = np.asarray(gt_file['coordinates'])
coordinates
# Out:
# array([[329,  18],
#        [  7,  21],
#        [283,  63],
#        [373,  72],
#        [509,  78],
#        [321,  79],
#        [426,  91],
#        [393,  99],
#        [316, 122],
#        [342, 127],
#        [117, 146],
#        [282, 158],
#        [384, 167],
#        [557, 181],
#        [295, 186],
#        [465, 212],
#        [522, 227],
#        [454, 228],
#        [601, 228],
#        [295, 229],
#        [ 83, 247],
#        [573, 257],
#        [303, 261],
#        [ 36, 286],
#        [603, 298],
#        [104, 318],
#        [443, 335],
#        [ 81, 335],
#        [356, 335],
#        [129, 362],
#        [417, 363],
#        [110, 381],
#        [451, 406],
#        [196, 420],
#        [424, 445],
#        [330, 453],
#        [104, 459],
#        [375, 469],
#        [241, 482],
#        [581, 485],
#        [125, 497],
#        [ 30, 501],
#        [632, 504],
#        [309, 516],
#        [395, 519],
#        [214, 539],
#        [268, 548],
# ...
